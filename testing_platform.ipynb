# %%
# %load_ext autoreload
# %autoreload 2
from spotify_playlist_maker import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
optimal_playlist = '''
If i can't 
let it go 
out of my mind
I'm scared
my stupid heart
with you
#
2
24
'''
optimal_playlist2 = '''
If i can't 
let it go 
out of my mind
I'm scared
my stupid heart
my stupid mouth 
will try
finding a way home 
home to you
letting you know 
all the ways
I want the world to stop 
with you
'''

poem_str1 = '''
If i can't let it go out of my mind
I'm scared
my stupid heart
my stupid mouth will try
finding a way home home to you
letting you know all the ways
I want the world to stop with you
'''

poem_str2 = '''
If i can't let it go out of my mind I'm scared my stupid heart my stupid mouth will try finding a way home home to you letting you know all the ways I want the world to stop with you
'''

poem_str3 = "If i can't let it go out of my mind"

# %%
make_playlist= spotify_playlist_maker(poem_str3)
make_playlist.make_playlist()
# Out:
# str_to_playlist(<spotify_playlist_maker.spotify_playlist_maker object at 0x107aa9990>, "If i can't let it go out of my mind")
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# [[u'"out of my mind" by James Blunt',
#   u'"If i can\'t" by 50 Cent',
#   u'"let it go" by James Bay']]

# %%
# %timeit make_playlist.make_playlist(poem_str2)
# Out:
# str_to_playlist(<spotify_playlist_maker.spotify_playlist_maker object at 0x107aa9990>, '')
# str_to_playlist(<spotify_playlist_maker.spotify_playlist_maker object at 0x107aa9990>, "If i can't let it go out of my mind I'm scared my stupid heart my stupid mouth will try finding a way home home to you letting you know all the ways I want the world to stop with you")
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...3secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secsretrying ...3secs
#
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...4secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...5secs
# retrying ...5secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...6secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...5secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...6secs
# retrying ...6secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...6secs
# retrying ...4secs
# retrying ...7secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...7secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...8secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# 1 loops, best of 3: 2.86 µs per loop
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /Users/Ajay/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
# %timeit make_playlist.make_playlist(optimal_playlist)
# Out:
# 100000 loops, best of 3: 7.21 µs per loop

# %%
make_test = spotify_playlist_maker(optimal_playlist)
make_test.make_playlist()
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...2secs
# retrying ...3secs
# retrying ...4secs
# retrying ...5secs
# retrying ...6secs
# retrying ...7secs
# retrying ...8secs
# retrying ...9secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...2secs
# retrying ...3secs
# retrying ...4secs
# retrying ...5secs
# retrying ...6secs
# retrying ...7secs
# retrying ...8secs
# retrying ...9secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...2secs
# retrying ...3secs
# retrying ...4secs
# retrying ...5secs
# retrying ...6secs
# retrying ...7secs
# retrying ...8secs
# retrying ...9secs
# retrying ...10secs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-6e4f8e78dbe4> in <module>()
#       1 make_test = spotify_playlist_maker(optimal_playlist)
# ----> 2 make_test.make_playlist()
#
# /Users/Ajay/spotify/spotify_playlist_maker.py in make_playlist(self, input_str)
#     133         for track_name in sorted_bag[0][1]:
#     134             playlist_str = '"' + track_name + '"' + ' by ' + self.track_name_to_artist_lookup[track_name]
# --> 135             output_to_display.append(playlist_str)
#     136         return output_to_display
#     137
#
# /Users/Ajay/spotify/spotify_playlist_maker.py in loop_through_sentence_by_sentence(self, input_str)
#     138     def make_playlist(self, input_str=None):
#     139         '''
# --> 140         I: any string to make into playlist_str
#     141         O: list of track_names on a playlist
#     142         '''
#
# /Users/Ajay/spotify/helpers.py in memoized(*args)
#      16         except KeyError:
#      17             # nothing was cached for those args. let's fix that.
# ---> 18             result = stored_results[args] = fn(*args)
#      19             return result
#      20     return memoized
#
# /Users/Ajay/spotify/spotify_playlist_maker.py in str_to_playlist(self, input_str)
#     111
#     112         # sorts by longest track name first for no particular reason
# --> 113         return sorted(output, key=lambda x: len(x[0]))
#     114
#     115     # this avoids unnecessary api calls and saves time for algo optimization
#
# /Users/Ajay/spotify/spotify_playlist_maker.py in query_all_possibilities_parallelized(self, input_str, max_workers)
#      44             for n in range(len(input_str.split()))[::-1]: #change to xrange
#      45                 #maps the function to the the distributable task_list
# ---> 46                 future = executor.submit(self.api_call_func, (input_str, n))
#      47                 output.append(future)
#      48
#
# /Users/Ajay/anaconda/lib/python2.7/site-packages/concurrent/futures/_base.pyc in __exit__(self, exc_type, exc_val, exc_tb)
#     602
#     603     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 604         self.shutdown(wait=True)
#     605         return False
#
# /Users/Ajay/anaconda/lib/python2.7/site-packages/concurrent/futures/thread.pyc in shutdown(self, wait)
#     131         if wait:
#     132             for t in self._threads:
# --> 133                 t.join()
#     134     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /Users/Ajay/anaconda/lib/python2.7/threading.pyc in join(self, timeout)
#     947             if timeout is None:
#     948                 while not self.__stopped:
# --> 949                     self.__block.wait()
#     950                 if __debug__:
#     951                     self._note("%s.join(): thread stopped", self)
#
# /Users/Ajay/anaconda/lib/python2.7/threading.pyc in wait(self, timeout)
#     337         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     338             if timeout is None:
# --> 339                 waiter.acquire()
#     340                 if __debug__:
#     341                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:

# %%
make_test = spotify_playlist_maker("If I can't")
make_test.make_playlist()
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...2secs
# retrying ...3secs
# retrying ...3secs
# retrying ...4secs
# retrying ...4secs
# retrying ...5secs
# retrying ...5secs
# retrying ...6secs
# retrying ...6secs
# retrying ...7secs
# retrying ...7secs
# retrying ...8secs
# retrying ...8secs
# retrying ...9secs
# retrying ...9secs
# retrying ...10secs
# retrying ...10secs
# retrying ...1secs
# retrying ...2secs
# retrying ...3secs
# retrying ...4secs
# retrying ...5secs
# retrying ...6secs
# retrying ...7secs
# retrying ...8secs
# retrying ...9secs
# retrying ...10secs
# []
